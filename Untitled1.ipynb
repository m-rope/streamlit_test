# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_path = '/Users/mattiaropelato/python/streamlit_test/dataset/f1_23_09_22/'

df = pd.read_csv(df_path + 'driver_avgPos_circuit.csv')

# %%
df.loc[df['driverRef']=='max_verstappen', 'pilot'] = 'verstappen'
# Out:
#          driverRef     location       pilot  somma      media
# 0         hamilton    Abu Dhabi    hamilton     13   4.846154
# 1         hamilton     Budapest    hamilton     16   3.375000
# 2         hamilton     Montmeló    hamilton     16   5.250000
# 3         hamilton        Monza    hamilton     15   6.066667
# 4         hamilton       Sakhir    hamilton     15   3.400000
# 5         hamilton  Silverstone    hamilton     17   3.058824
# 6         hamilton          Spa    hamilton     15   7.133333
# 7         hamilton    Spielberg    hamilton     11   4.000000
# 8          leclerc    Abu Dhabi     leclerc      4   8.250000
# 9          leclerc     Budapest     leclerc      5  11.800000
# 10         leclerc     Montmeló     leclerc      5  11.800000
# 11         leclerc        Monza     leclerc      4   8.500000
# 12         leclerc       Sakhir     leclerc      6   8.666667
# 13         leclerc  Silverstone     leclerc      6   5.833333
# 14         leclerc          Spa     leclerc      4  10.250000
# 15         leclerc    Spielberg     leclerc      7   6.857143
# 16  max_verstappen    Abu Dhabi  verstappen      7   4.571429
# 17  max_verstappen     Budapest  verstappen      8   5.875000
# 18  max_verstappen     Montmeló  verstappen      8   5.250000
# 19  max_verstappen        Monza  verstappen      7  11.000000
# 20  max_verstappen       Sakhir  verstappen      9  11.888889
# 21  max_verstappen  Silverstone  verstappen      9   8.000000
# 22  max_verstappen          Spa  verstappen      7   9.285714
# 23  max_verstappen    Spielberg  verstappen     10   5.900000
# 24          norris    Abu Dhabi      norris      3   6.666667
# 25          norris     Budapest      norris      4  11.000000
# 26          norris     Montmeló      norris      4  11.500000
# 27          norris        Monza      norris      3   5.333333
# 28          norris       Sakhir      norris      5   7.800000
# 29          norris  Silverstone      norris      5   7.000000
# 30          norris          Spa      norris      3  10.666667
# 31          norris    Spielberg      norris      6   4.833333
# 32         russell    Abu Dhabi     russell      3  16.666667
# 33         russell     Budapest     russell      4  11.250000
# 34         russell     Montmeló     russell      4  12.750000
# 35         russell        Monza     russell      3  12.333333
# 36         russell       Sakhir     russell      5  10.800000
# 37         russell  Silverstone     russell      5  14.800000
# 38         russell          Spa     russell      3  12.000000
# 39         russell    Spielberg     russell      6  13.833333

# %%
fig, axes = plt.subplots(figsize=(15,5))
sns.lineplot(data=df, x='location', y='media', hue='driverRef')
sns.scatterplot(data=df, x='location', y='media', hue='driverRef', size='somma', sizes=(50,400), legend=False)
axes.invert_yaxis()
axes.set_facecolor('k')
axes.xaxis.grid()
fig.set_facecolor('xkcd:steel grey')
axes.grid(linewidth=.3)
plt.legend(loc='lower center')
plt.show()
